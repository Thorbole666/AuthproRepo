# %% [markdown]
# <a href="https://colab.research.google.com/github/Thorbole666/AuthproRepo/blob/main/Penguindataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/penguins.csv")

# %%
print(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.tail(5)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
df.values #display only values
# Out:
# array([['Adelie', 'Torgersen', 39.1, ..., 181.0, 3750.0, 'MALE'],
#        ['Adelie', 'Torgersen', 39.5, ..., 186.0, 3800.0, 'FEMALE'],
#        ['Adelie', 'Torgersen', 40.3, ..., 195.0, 3250.0, 'FEMALE'],
#        ...,
#        ['Gentoo', 'Biscoe', 50.4, ..., 222.0, 5750.0, 'MALE'],
#        ['Gentoo', 'Biscoe', 45.2, ..., 212.0, 5200.0, 'FEMALE'],
#        ['Gentoo', 'Biscoe', 49.9, ..., 213.0, 5400.0, 'MALE']],
#       dtype=object)

# %%
df.shape #display rows and cols
# Out:
# (344, 7)

# %%
df.size #get number of element present
# Out:
# 2408

# %%
df.ndim #get dimention of dataset
# Out:
# 2

# %%
df.count() #It count  no of each element present in each column
# Out:
# species              344
# island               344
# bill_length_mm       342
# bill_depth_mm        342
# flipper_length_mm    342
# body_mass_g          342
# sex                  333
# dtype: int64

# %%
df.dtypes #get data type of each col.
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
df.empty#check whether empty elements present or not
# Out:
# False

# %%
df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %%
df['island'].is_unique #varname['column_name'].is_unique
# Out:
# False

# %%
df.nunique()#get no of unique values in  each column
# Out:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# dtype: int64

# %%
df.info()#gives col info,memory usage etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()#it gives statistical information about dataset
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.describe(include="object") #number object all
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %%
df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# ...

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df['species'] #varname['Column] -->Select particular column
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
df[['species','island']] #varname[['col1','col2'..]]  --->select multiple columns
# Out:
#     species     island
# 0    Adelie  Torgersen
# 1    Adelie  Torgersen
# 2    Adelie  Torgersen
# 3    Adelie  Torgersen
# 4    Adelie  Torgersen
# ..      ...        ...
# 339  Gentoo     Biscoe
# 340  Gentoo     Biscoe
# 341  Gentoo     Biscoe
# 342  Gentoo     Biscoe
# 343  Gentoo     Biscoe
#
# [344 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.nlargest(2,'body_mass_g')#display elements in desc to asc order
#varname()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 237  Gentoo  Biscoe            49.2           15.2              221.0
# 253  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex
# 237       6300.0  MALE
# 253       6050.0  MALE

# %%
df.nsmallest(5,'body_mass_g') #display elements in asc to desc order
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 190  Chinstrap   Dream            46.9           16.6              192.0
# 58      Adelie  Biscoe            36.5           16.6              181.0
# 64      Adelie  Biscoe            36.4           17.1              184.0
# 54      Adelie  Biscoe            34.5           18.1              187.0
# 98      Adelie   Dream            33.1           16.1              178.0
#
#      body_mass_g     sex
# 190       2700.0  FEMALE
# 58        2850.0  FEMALE
# 64        2850.0  FEMALE
# 54        2900.0  FEMALE
# 98        2900.0  FEMALE

# %%
df.sample()#display random records
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 187  Chinstrap  Dream            47.5           16.8              199.0
#
#      body_mass_g     sex
# 187       3900.0  FEMALE

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=344, step=1),
#  Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#         'flipper_length_mm', 'body_mass_g', 'sex'],
#        dtype='object')]

# %%
df.isna()#checks for null data. isna is primary function
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
df.isnull()#checks for null data and isnull is alias
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
df.index #get information such as its range like  start,end and sv
# Out:
# RangeIndex(start=0, stop=344, step=1)

# %%
df.empty#check whether dataset is empty or not
# Out:
# False

# %%
df.T#T is transpose which converts rows to cols and cols to rows.
# Out:
#                          0          1          2          3          4    \
# species               Adelie     Adelie     Adelie     Adelie     Adelie
# island             Torgersen  Torgersen  Torgersen  Torgersen  Torgersen
# bill_length_mm          39.1       39.5       40.3        NaN       36.7
# bill_depth_mm           18.7       17.4       18.0        NaN       19.3
# flipper_length_mm      181.0      186.0      195.0        NaN      193.0
# body_mass_g           3750.0     3800.0     3250.0        NaN     3450.0
# sex                     MALE     FEMALE     FEMALE        NaN     FEMALE
#
#                          5          6          7          8          9    ...  \
# species               Adelie     Adelie     Adelie     Adelie     Adelie  ...
# island             Torgersen  Torgersen  Torgersen  Torgersen  Torgersen  ...
# bill_length_mm          39.3       38.9       39.2       34.1       42.0  ...
# ...

# %%
df.memory_usage()#indicate memeory used by each column
# Out:
# Index                 132
# species              2752
# island               2752
# bill_length_mm       2752
# bill_depth_mm        2752
# flipper_length_mm    2752
# body_mass_g          2752
# sex                  2752
# dtype: int64

# %%
df.value_counts()#count occurrences of unique values.
# Out:
# species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# Gentoo   Biscoe  59.6            17.0           230.0              6050.0       MALE      1
# Adelie   Biscoe  34.5            18.1           187.0              2900.0       FEMALE    1
#                  35.0            17.9           190.0              3450.0       FEMALE    1
#                                                 192.0              3725.0       FEMALE    1
#                  35.3            18.9           187.0              3800.0       FEMALE    1
#                                                                                          ..
#                  38.1            16.5           198.0              3825.0       FEMALE    1
#                  37.9            18.6           193.0              2925.0       FEMALE    1
#                                                 172.0              3150.0       FEMALE    1
# ...

# %%
df[2:11:2]#display or select particular data using filter
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
#
#     body_mass_g     sex
# 2        3250.0  FEMALE
# 4        3450.0  FEMALE
# 6        3625.0  FEMALE
# 8        3475.0     NaN
# 10       3300.0     NaN

# %%
df[['species','body_mass_g']] #varname[[col1,col2]]
# Out:
#     species  body_mass_g
# 0    Adelie       3750.0
# 1    Adelie       3800.0
# 2    Adelie       3250.0
# 3    Adelie          NaN
# 4    Adelie       3450.0
# ..      ...          ...
# 339  Gentoo          NaN
# 340  Gentoo       4850.0
# 341  Gentoo       5750.0
# 342  Gentoo       5200.0
# 343  Gentoo       5400.0
#
# [344 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df[['species','island','body_mass_g'][0:10:2]]    #df[['column1'.'column2','column3'][start:stop:step]]
# Out:
#     species  body_mass_g
# 0    Adelie       3750.0
# 1    Adelie       3800.0
# 2    Adelie       3250.0
# 3    Adelie          NaN
# 4    Adelie       3450.0
# ..      ...          ...
# 339  Gentoo          NaN
# 340  Gentoo       4850.0
# 341  Gentoo       5750.0
# 342  Gentoo       5200.0
# 343  Gentoo       5400.0
#
# [344 rows x 2 columns]

# %%
df.get(['species','island','body_mass_g'])#display multiple columns.
# Out:
#     species     island  body_mass_g
# 0    Adelie  Torgersen       3750.0
# 1    Adelie  Torgersen       3800.0
# 2    Adelie  Torgersen       3250.0
# 3    Adelie  Torgersen          NaN
# 4    Adelie  Torgersen       3450.0
# ..      ...        ...          ...
# 339  Gentoo     Biscoe          NaN
# 340  Gentoo     Biscoe       4850.0
# 341  Gentoo     Biscoe       5750.0
# 342  Gentoo     Biscoe       5200.0
# 343  Gentoo     Biscoe       5400.0
#
# [344 rows x 3 columns]

# %%
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE

# %%
df.take([3],axis=1)#display particular column but here we need to pass its index ans axis=1 for column
# Out:
#      bill_depth_mm
# 0             18.7
# 1             17.4
# 2             18.0
# 3              NaN
# 4             19.3
# ..             ...
# 339            NaN
# 340           14.3
# 341           15.7
# 342           14.8
# 343           16.1
#
# [344 rows x 1 columns]

# %%
df.take([5],axis=0)#display particular column but here we need to pass its index ans axis=0 for rows
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g   sex
# 5       3650.0  MALE

# %% [markdown]
# **Handling missing data**

# %% [markdown]
# Q1 Find columns containing missing value

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g',
#        'sex'],
#       dtype='object')

# %% [markdown]
# Q2 Find the percentage of missing data

# %%
df.isnull().sum()/len(df)*100
# Out:
# species              0.000000
# island               0.000000
# bill_length_mm       0.581395
# bill_depth_mm        0.581395
# flipper_length_mm    0.581395
# body_mass_g          0.581395
# sex                  3.197674
# dtype: float64

# %% [markdown]
# #OR

# %%
df.isna().sum()/len(df)*100
# Out:
# species              0.000000
# island               0.000000
# bill_length_mm       0.581395
# bill_depth_mm        0.581395
# flipper_length_mm    0.581395
# body_mass_g          0.581395
# sex                  3.197674
# dtype: float64

# %% [markdown]
# Q3 Drop the rows with massive values

# %%
df.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# Q4 Check for duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Q5 How to remove duplicate rows

# %%
df.drop_duplicates()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# Q6 what is shape and size of dataset

# %%
df.shape
# Out:
# (344, 7)

# %%
df.size
# Out:
# 2408

# %% [markdown]
# Q7 Summary of dataset

# %%
df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# ...

# %% [markdown]
# Q8 Count penguines per island

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %% [markdown]
# Q9 Find average bill_length and bill_depth for each species

# %%
df.groupby('species')[["bill_length_mm","bill_depth_mm"]].mean()
# Out:
#            bill_length_mm  bill_depth_mm
# species
# Adelie          38.791391      18.346358
# Chinstrap       48.833824      18.420588
# Gentoo          47.504878      14.982114

# %% [markdown]
# Q10 Sort dataset by flipper_length_mm in descending order

# %%
srt=df.sort_values('flipper_length_mm',ascending=False)
srt[['species','flipper_length_mm']].head()
# Out:
#     species  flipper_length_mm
# 283  Gentoo              231.0
# 335  Gentoo              230.0
# 333  Gentoo              230.0
# 285  Gentoo              230.0
# 309  Gentoo              230.0
